# %% [markdown]
# # Plotting Financial Data with Plotly: Linear Regressions, 20 day moving averages, Bollinger Bands for Technical Analysis

# %% [markdown]
# ### We are using Google Colaboratory.  Think of it as the Google Docs version of Jupyter notebook.  These 'Colaboratory' notebooks come preinstalled with all of the necessary Python code including GPU configurations.  If you need other packages, they are a 'pip' or 'conda' install away

# %%
! conda install plotly -y

# %% [markdown]
# #### Since colaboratory is hosted on a different computer but is a plotting tool, we just have to add some code to get it to work in google Colaboratory so that it renders on our screen

# %%
import warnings
warnings.filterwarnings("ignore")

#https://colab.research.google.com/notebook#fileId=14oudHx5e5r7hm1QcbZ24FVHXgVPD0k8f
import IPython
def configure_plotly_browser_state():
    display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
IPython.get_ipython().events.unregister('pre_run_cell', configure_plotly_browser_state)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-10d843693c9b> in <module>()
# ----> 1 IPython.get_ipython().events.unregister('pre_run_cell', configure_plotly_browser_state)
#       2
#       3 import warnings
#       4 warnings.filterwarnings("ignore")
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/events.py in unregister(self, event, function)
#      76                 pass
#      77
# ---> 78         raise ValueError('Function {!r} is not registered as a {} callback'.format(function, event))
#      79
#      80     def trigger(self, event, *args, **kwargs):
#
# ValueError: Function <function configure_plotly_browser_state at 0x10ae50048> is not registered as a pre_run_cell callback

# %% [markdown]
# ### Let's pull Historical data on Microsoft using the Quandl API

# %%
import requests

api_key = 'uqsmdRnZoXuRF3LRev__'
parameters = {'api_key':api_key}

initial_url = 'https://www.quandl.com/api/v3/datasets/'
dataset_group = 'EOD/'
dataset = 'MSFT'
datatype = '.json'

final_url = initial_url + dataset_group + dataset + datatype

results = requests.get(final_url, params=parameters)

APIresults = results.json()

APIresults.keys()
# Out:
# dict_keys(['dataset'])

# %%
APIresults['dataset'].keys()
# Out:
# dict_keys(['id', 'dataset_code', 'database_code', 'name', 'description', 'refreshed_at', 'newest_available_date', 'oldest_available_date', 'column_names', 'frequency', 'type', 'premium', 'limit', 'transform', 'column_index', 'start_date', 'end_date', 'data', 'collapse', 'order', 'database_id'])

# %% [markdown]
# #### So the data we want exists as a list of lists in the key '**data**' and the column names of that data exist in '**columns_names**' attribute.

# %%
APIresults['dataset']['column_names']
# Out:
# ['Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Dividend',
#  'Split',
#  'Adj_Open',
#  'Adj_High',
#  'Adj_Low',
#  'Adj_Close',
#  'Adj_Volume']

# %%
APIresults['dataset']['data'][:2]
# Out:
# [['2018-11-16',
#   107.08,
#   108.88,
#   106.8,
#   108.29,
#   33502121.0,
#   0.0,
#   1.0,
#   107.08,
#   108.88,
#   106.8,
#   108.29,
#   33502121.0],
#  ['2018-11-15',
#   104.99,
#   107.8,
#   103.91,
#   107.28,
#   38505165.0,
#   0.0,
#   1.0,
#   104.99,
#   107.8,
#   103.91,
#   107.28,
#   38505165.0]]

# %% [markdown]
# ### Convert the results into a Pandas DataFrame

# %%
import pandas as pd

msft = pd.DataFrame(data = APIresults['dataset']['data'], 
                    columns = APIresults['dataset']['column_names'])

msft.head(2)
# Out:
#          Date    Open    High     Low   Close      Volume  Dividend  Split  \
# 0  2018-11-16  107.08  108.88  106.80  108.29  33502121.0       0.0    1.0
# 1  2018-11-15  104.99  107.80  103.91  107.28  38505165.0       0.0    1.0
#
#    Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# 0    107.08    108.88   106.80     108.29  33502121.0
# 1    104.99    107.80   103.91     107.28  38505165.0

# %% [markdown]
# ### Sort the dataframe so that the earliest date comes first

# %%
print(type(msft['Date'][0]))

msft['Date'] = pd.to_datetime(msft['Date'])

print(type(msft['Date'][0]))

msft.set_index('Date',inplace=True)

msft.sort_index(inplace=True)
# Out:
# <class 'str'>
# <class 'pandas._libs.tslib.Timestamp'>

# %%
msft.head(2)
# Out:
#             Open   High   Low  Close     Volume  Dividend  Split  Adj_Open  \
# Date
# 1986-03-13  25.5  29.25  25.5   28.0  3582600.0       0.0    1.0  0.057937
# 1986-03-14  28.0  29.50  28.0   29.0  1070000.0       0.0    1.0  0.063617
#
#             Adj_High   Adj_Low  Adj_Close    Adj_Volume
# Date
# 1986-03-13  0.066457  0.057937   0.063617  1.031789e+09
# 1986-03-14  0.067025  0.063617   0.065889  3.081600e+08

# %% [markdown]
# ### Filter for years between 2010 and 2017

# %%
print(len(msft))

msft2 = msft[ (msft.index >= "2010-01-01") & (msft.index <= "2017-01-01") ]

print(len(msft2))
# Out:
# 8241
# 1762

# %% [markdown]
# ### We will be using a graphing package called Plotly in order to create an OHLC (Open High Low Close) graph for the Microsoft Stock Data

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,iplot
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ### First we create the chart data

# %%
ohlc_line = go.Ohlc(x = msft2.index,
                       open = msft2['Open'],
                       high = msft2['High'],
                       low = msft2['Low'],
                       close = msft2['Close'],
                       name = 'OHLC')

# insert the ohlc_line into a list, per the plotly functionality

data = [ ohlc_line ]

# plot the data
iplot(data)
# Out:
# <div id="a4c18560-8067-42f4-aba0-aba6f8444f74" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a4c18560-8067-42f4-aba0-aba6f8444f74", [{"close": [30.95, 30.96, 30.77, 30.452, 30.66, 30.27, 30.07, 30.35, 30.96, 30.86, 31.1, 30.585, 30.01, 28.96, 29.32, 29.5, 29.67, 29.16, 28.18, 28.41, 28.46, 28.63, 27.84, 28.02, 27.72, 28.01, 27.99, 28.12, 27.93, 28.35, 28.59, 28.969, 28.77, 28.73, 28.33, 28.63, 28.6, 28.67, 29.02, 28.46, 28.46, 28.63, 28.5875, 28.63, 28.8, 28.97, 29.18, 29.27, 29.29, 29.37, 29.63, 29.61, 29.59, 29.6, 29.88, 29.65, 30.01, 29.66, 29.59, 29.77, 29.2875, 29.16, 29.27, 29.32, 29.35, 29.92, 30.34, 30.32, 30.45, 30.82, 30.87, 30.67, 31.039, 31.36, 31.332, 31.39, 30.96, 31.11, 30.845, 30.91, 31.003, 30.535, 30.86, 30.13, 29.85, 28.98, 28.21, 28.94, 28.88, 29.44, 29.24, 28.93, 28.94, 28
26.47, 26.78, 26.59, 27.54, 27.06, 27.095, 27.53, 27.91, 28.08, 27.33, 27.72, 27.4, 27.27, 26.8, 26.92, 25.94, 25.68, 24.48, 25.58, 24.2, 25.19, 25.1, 25.51, 25.35, 25.245, 24.67, 24.05, 23.98, 24.72, 24.9, 24.57, 25.25, 25.84, 26.23, 26.6, 26.21, 25.8, 25.51, 26.0, 26.22, 25.74, 25.89, 26.04, 26.5, 26.99, 27.12, 27.21, 26.98, 25.99, 25.06, 25.06, 25.44, 25.67, 25.575, 25.45, 24.89, 24.53, 25.34, 25.89, 26.34, 26.25, 26.94, 27.0, 26.96, 27.18, 27.27, 26.98, 27.31, 27.13, 27.04, 27.16, 27.19, 26.81, 26.59, 27.25, 26.98, 26.63, 25.99, 26.01, 26.53, 26.25, 26.8, 27.16, 26.2, 26.28, 26.91, 26.76, 26.74, 26.07, 25.54, 25.3, 25.0, 24.79, 24.47, 24.3, 24.87, 24.84, 25.58, 25.28, 25.22, 25.7, 25.66, 25.6, 25.4, 25.7, 25.51, 25.76, 25.59, 25.56, 26.0, 25.53, 26.025, 25.76, 25.81, 26.03, 26.04, 25.82, 26.02, 25.96, 26.765, 27.4, 27.68, 28.105, 27.74, 27.84, 27.72, 28.0, 28.25, 28.255, 28.23, 28.12, 29.71, 29.73, 29.34, 29.56, 29.5, 2 ...

# %% [markdown]
# ### Eh, scrolling and zooming and dynamic changes are cool, but I want to add some extra parts to this graph....including:
#
# - a line showing when Satya Nadella became CEO
# - titles for graph, x-axis, y-axis
# - A line showing the Close values

# %%
# "Layout" contains the extra visuals in the graph

layout = go.Layout({
    'title': "Microsoft Historical Stock Data",
    'yaxis': {'title': 'MSFT Stock ($)'},
    'xaxis' : {'rangeslider':{'visible':False}},
    'shapes': [{
        'x0': '2014-02-04', 'x1': '2014-02-04',
        'y0' : 0, 'y1': 1, 'xref': 'x', 'yref':'paper',
        'line' : {'color': 'rgb(30,30,30)', 'width':1}
    }],
    'annotations': [{
        'x': '2014-02-04', 'y':0.05, 'xref': 'x', 'yref': 'paper',
        'showarrow':False, 'xanchor': 'left',
        'text': 'Satya Nadella becomes CEO'
    }]
})

#### now lets create the line chart connecting all the close values together with a black line

close_line = go.Scatter(
    x=msft2.index,
    y = msft2['Close'],
    name= 'Closing $',
    line = {'color' : 'black','width' : 0.3 }
)

# create a data list containing all the charts we want to graph
data = [ ohlc_line, close_line ]

#  combine them with the layouts into a figure

fig = go.Figure(data=data, layout = layout)

iplot(fig)
# Out:
# <div id="35195523-6d0e-4ae4-984e-706797dd6e67" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e40b6d35-4d03-4546-9190-fa2ed26fbdea", [{"line": {"color": "black", "width": 1}, "name": "Closing $", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-1 ...

# %% [markdown]
# ### Add a Regression line with SciKit Learn

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

train_x = msft3.index.value_counts().cumsum().values.reshape(-1,1)

#pandas['column].values -> converts column to numpy array

train_y = msft3['Close'].values.reshape(-1,1)

print(train_x[:5])
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %% [markdown]
# ### Create a Linear Model

# %%
# create a linear model from the LinearRegression class
reg = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
# fit data to model
reg.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Create predictions and assign them to a new column in msft3

# %%
msft3['LinReg'] = reg.predict(train_x)

# %% [markdown]
# #### Show the coefficient and the exponent for:  y = mx + b

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# [57.90678566]
# [[0.11581527]]

# %%
msft3.head(2)
# Out:
#              Open   High     Low  Close      Volume  Dividend  Split  \
# Date
# 2017-01-03  62.79  62.84  62.125  62.58  20694101.0       0.0    1.0
# 2017-01-04  62.48  62.75  62.120  62.30  21339969.0       0.0    1.0
#
#              Adj_Open   Adj_High    Adj_Low  Adj_Close  Adj_Volume     LinReg
# Date
# 2017-01-03  60.377440  60.425519  59.737991  60.175508  20694101.0  58.022601
# 2017-01-04  60.079351  60.338977  59.733183  59.906267  21339969.0  58.138416

# %% [markdown]
# ### Graph it next to the Closing price data!

# %%
linreg_line = go.Scatter(
    x=msft3.index,
    y = msft3['LinReg'],
    name= 'Linear Regression',
    line = {'color' : 'blue','width' : 1 }
)

data = [ close_line, linreg_line]

iplot(data)
# Out:
# <div id="a7231aad-9131-4b8b-a725-c0fac035fc08" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a7231aad-9131-4b8b-a725-c0fac035fc08", [{"line": {"color": "black", "width": 1}, "name": "Closing $", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-1 ...

# %% [markdown]
# ### Create a 20 day moving average on the closing price values.  Whoo Rolling Averages!

# %%
msft3['20ma'] = msft3['Close'].rolling(20, min_periods=1).mean()

msft3.head(2)
# Out:
#              Open   High     Low  Close      Volume  Dividend  Split  \
# Date
# 2017-01-03  62.79  62.84  62.125  62.58  20694101.0       0.0    1.0
# 2017-01-04  62.48  62.75  62.120  62.30  21339969.0       0.0    1.0
#
#              Adj_Open   Adj_High    Adj_Low  Adj_Close  Adj_Volume     LinReg  \
# Date
# 2017-01-03  60.377440  60.425519  59.737991  60.175508  20694101.0  58.022601
# 2017-01-04  60.079351  60.338977  59.733183  59.906267  21339969.0  58.138416
#
#              20ma
# Date
# 2017-01-03  62.58
# 2017-01-04  62.44

# %% [markdown]
# ### Plot the 20 day moving average

# %%
ma_line = go.Scatter(
    x=msft3.index,
    y = msft3['20ma'],
    name= '20 Day MA',
    line = {'color' : 'green','width' : 1 }
)

data = [ close_line, linreg_line, ma_line]

iplot(data)
# Out:
# <div id="94018096-7174-49f7-b131-eecf87e48432" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("94018096-7174-49f7-b131-eecf87e48432", [{"line": {"color": "black", "width": 1}, "name": "Closing $", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-1 ...

# %% [markdown]
# ### Compute Bollinger Bands with the 20 day moving standard deviation and assign a lower and upper bound based on 20 Day MA +/- 2* 20 day MSD

# %%
# 20 day standard deviation

msft3['20sd'] = msft3['Close'].rolling(20, min_periods=1).std()

# %% [markdown]
# ### Create the bands

# %%
# Upper band and lower band
msft3['Upper'] = msft3['20ma'] + 2 * msft3['20sd']

msft3['Lower'] = msft3['20ma'] - 2 * msft3['20sd']

# %% [markdown]
# ### Graph the bans together with the stock price

# %%
Upper = go.Scatter(
    x=msft3.index,
    y = msft3['Upper'],
    name= 'Upper Band',
    fill = 'tonexty',
    line = {'color' : 'light green','width' : 1 }
)

Lower = go.Scatter(
    x=msft3.index,
    y = msft3['Lower'],
    name= 'Lower Band',
    fill = 'tonexty',
    line = {'color' : 'light green','width' : 1 }
)

data = [ close_line, Upper, Lower]

layout = go.Layout({
    'title' : 'Microsoft Stock with 20 Day MA Bollinger Bands',
    'yaxis' : {'title' : 'MSFT Stock ($)'},
    'xaxis' : {'rangeslider' : {'visible':False}}
})

fig = go.Figure(data=data,layout=layout)

iplot(fig)
# Out:
# <div id="c2404296-d007-430b-925b-61b0fefeede9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c2404296-d007-430b-925b-61b0fefeede9", [{"line": {"color": "black", "width": 1}, "name": "Closing $", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-1 ...

# %% [markdown]
# ### Let's create a signal book for buying and selling Microsoft Stock using the Bollinger Bands as signals

# %%
msft4 = msft3[['Close','Upper','Lower']]
msft4.head(2)
# Out:
#             Close     Upper     Lower
# Date
# 2017-01-03  62.58       NaN       NaN
# 2017-01-04  62.30  62.83598  62.04402

# %% [markdown]
# #### If the closing price is below the lower band, that is a 'buy' signal and if the closing price is above the upper band, that is a 'sell' signal

# %%
# create a new column called Signal

msft4['Signal'] = np.where(msft4['Close'] > msft4['Upper'],'SELL','HOLD')
msft4['Signal'] = np.where(msft4['Close'] < msft4['Lower'],'BUY',msft4['Signal'])

msft4 = msft4[msft4['Signal'] != 'HOLD']

msft4 = msft4[msft4['Signal'] != msft4['Signal'].shift(1)]

msft4['Symbol'] = 'MSFT'
msft4['Shares'] = 1000

msft5 = msft4

msft5
# Out:
#              Close       Upper       Lower Signal Symbol  Shares
# Date
# 2017-01-24   63.52   63.360715   62.016618   SELL   MSFT    1000
# 2017-08-10   71.41   74.549690   71.528310    BUY   MSFT    1000
# 2017-08-30   74.01   73.935255   71.582745   SELL   MSFT    1000
# 2017-12-04   81.08   85.387375   81.816625    BUY   MSFT    1000
# 2017-12-15   86.85   86.630036   80.903964   SELL   MSFT    1000
# 2018-02-08   85.01   95.984196   85.980804    BUY   MSFT    1000
# 2018-04-17   96.07   95.989556   87.217444   SELL   MSFT    1000
# 2018-06-27   97.54  103.254016   98.085984    BUY   MSFT    1000
# 2018-07-12  104.19  103.676964   97.229036   SELL   MSFT    1000
# 2018-10-10  106.16  117.329303  108.986697    BUY   MSFT    1000
