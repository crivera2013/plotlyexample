# %% [markdown]
# # Plotting Financial Data with Plotly: Linear Regressions, 20 day moving averages, Bollinger Bands for Technical Analysis

# %% [markdown]
# ### We are using Google Colaboratory.  Think of it as the Google Docs version of Jupyter notebook.  These 'Colaboratory' notebooks come preinstalled with all of the necessary Python code including GPU configurations.  If you need other packages, they are a 'pip' or 'conda' install away

# %%
! pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python2.7/dist-packages (1.12.12)
# Requirement already satisfied: requests in /usr/local/lib/python2.7/dist-packages (from plotly) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from plotly) (1.11.0)
# Requirement already satisfied: pytz in /usr/local/lib/python2.7/dist-packages (from plotly) (2018.7)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests->plotly) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests->plotly) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests->plotly) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests->plotly) (3.0.4)

# %% [markdown]
# #### Since colaboratory is hosted on a different computer but is a plotting tool, we just have to add some code to get it to work in google Colaboratory so that it renders on our screen

# %%
import warnings
warnings.filterwarnings("ignore")

#https://colab.research.google.com/notebook#fileId=14oudHx5e5r7hm1QcbZ24FVHXgVPD0k8f
import IPython
def configure_plotly_browser_state():
    display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
IPython.get_ipython().events.unregister('pre_run_cell', configure_plotly_browser_state)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-5-c956eaf910b2> in <module>()
# ----> 1 IPython.get_ipython().events.unregister('pre_run_cell', configure_plotly_browser_state)
#       2
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/events.pyc in unregister(self, event, function)
#      62     def unregister(self, event, function):
#      63         """Remove a callback from the given event."""
# ---> 64         self.callbacks[event].remove(function)
#      65
#      66     def trigger(self, event, *args, **kwargs):
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### Let's pull Historical data on Microsoft using the Quandl API

# %%
import requests

api_key = 'uqsmdRnZoXuRF3LRev__'
parameters = {'api_key':api_key}

initial_url = 'https://www.quandl.com/api/v3/datasets/'
dataset_group = 'EOD/'
dataset = 'MSFT'
datatype = '.json'

final_url = initial_url + dataset_group + dataset + datatype

results = requests.get(final_url, params=parameters)

APIresults = results.json()

APIresults.keys()
# Out:
# [u'dataset']

# %%
APIresults['dataset'].keys()
# Out:
# [u'dataset_code',
#  u'column_names',
#  u'newest_available_date',
#  u'description',
#  u'end_date',
#  u'data',
#  u'start_date',
#  u'limit',
#  u'transform',
#  u'order',
#  u'refreshed_at',
#  u'frequency',
#  u'database_code',
#  u'oldest_available_date',
#  u'collapse',
#  u'premium',
#  u'database_id',
#  u'column_index',
#  u'type',
#  u'id',
#  u'name']

# %% [markdown]
# #### So the data we want exists as a list of lists in the key '**data**' and the column names of that data exist in '**columns_names**' attribute.

# %%
APIresults['dataset']['column_names']
# Out:
# [u'Date',
#  u'Open',
#  u'High',
#  u'Low',
#  u'Close',
#  u'Volume',
#  u'Dividend',
#  u'Split',
#  u'Adj_Open',
#  u'Adj_High',
#  u'Adj_Low',
#  u'Adj_Close',
#  u'Adj_Volume']

# %%
APIresults['dataset']['data'][:2]
# Out:
# [[u'2018-11-16',
#   107.08,
#   108.88,
#   106.8,
#   108.29,
#   33502121.0,
#   0.0,
#   1.0,
#   107.08,
#   108.88,
#   106.8,
#   108.29,
#   33502121.0],
#  [u'2018-11-15',
#   104.99,
#   107.8,
#   103.91,
#   107.28,
#   38505165.0,
#   0.0,
#   1.0,
#   104.99,
#   107.8,
#   103.91,
#   107.28,
#   38505165.0]]

# %% [markdown]
# ### Convert the results into a Pandas DataFrame

# %%
import pandas as pd

msft = pd.DataFrame(data = APIresults['dataset']['data'], 
                    columns = APIresults['dataset']['column_names'])

msft.head(2)
# Out:
#          Date    Open    High     Low   Close      Volume  Dividend  Split  \
# 0  2018-11-16  107.08  108.88  106.80  108.29  33502121.0       0.0    1.0
# 1  2018-11-15  104.99  107.80  103.91  107.28  38505165.0       0.0    1.0
#
#    Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# 0    107.08    108.88   106.80     108.29  33502121.0
# 1    104.99    107.80   103.91     107.28  38505165.0

# %% [markdown]
# ### Sort the dataframe so that the earliest date comes first

# %%
print(type(msft['Date'][0]))

msft['Date'] = pd.to_datetime(msft['Date'])

print(type(msft['Date'][0]))

msft.set_index('Date',inplace=True)

msft.sort_index(inplace=True)
# Out:
# <type 'unicode'>
# <class 'pandas._libs.tslib.Timestamp'>

# %%
msft.head(2)
# Out:
#             Open   High   Low  Close     Volume  Dividend  Split  Adj_Open  \
# Date
# 1986-03-13  25.5  29.25  25.5   28.0  3582600.0       0.0    1.0  0.057937
# 1986-03-14  28.0  29.50  28.0   29.0  1070000.0       0.0    1.0  0.063617
#
#             Adj_High   Adj_Low  Adj_Close    Adj_Volume
# Date
# 1986-03-13  0.066457  0.057937   0.063617  1.031789e+09
# 1986-03-14  0.067025  0.063617   0.065889  3.081600e+08

# %% [markdown]
# ### Filter for years between 2010 and 2017

# %%
print(len(msft))

msft2 = msft[ (msft.index >= "2010-01-01") & (msft.index <= "2017-01-01") ]

print(len(msft2))
# Out:
# 8241
# 1762

# %% [markdown]
# ### We will be using a graphing package called Plotly in order to create an OHLC (Open High Low Close) graph for the Microsoft Stock Data

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,iplot
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ### First we create the chart data

# %%
ohlc_line = go.Ohlc(x = msft2.index,
                       open = msft2['Open'],
                       high = msft2['High'],
                       low = msft2['Low'],
                       close = msft2['Close'],
                       name = 'OHLC')

# insert the ohlc_line into a list, per the plotly functionality

data = [ ohlc_line ]

# plot the data
configure_plotly_browser_state()
iplot(data)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="c4f28ede-bcc6-4186-816b-c01944f6ccf9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c4f28ede-bcc6-4186-816b-c01944f6ccf9", [{"name": "OHLC", "type": "ohlc", "high": [31.1, 31.1, 31.08, 30.7, 30.88, 30.76, 30.4, 30.52, 31.1, 31.24, 31.24, 30.94, 30.72, 30.2, 29.66, 29.85, 29.82, 29.87, 29.92, 28.48, 28.5, 28.79, 28.5, 28.28, 28.08, 28.34, 28.24, 28.4, 28.06, 28.37, 28.65, 29.03, 28.92, 28.94, 28.83, 28.79, 28.65, 28.85, 29.05, 29.3, 28.61, 28.65, 28.68, 28.93, 29.11, 29.11, 29.19, 29.38, 29.37, 29.49, 29.87, 29.72, 29.9, 29.7, 29.9, 29.85, 30.57, 30.2, 29.82, 29.86, 29.72, 29.54, 29.425, 29.58, 29.56, 29.975, 30.41, 30.49, 30.5, 31.0, 30.95, 30.98, 31.25, 31.44, 31.5, 31.53, 31.58, 31
27.01, 26.9295, 26.9, 27.64, 27.35, 27.31, 27.55, 28.09, 28.145, 27.985, 28.07, 27.71, 27.685, 27.45, 27.0, 26.87, 26.1, 25.6, 25.62, 25.09, 25.38, 25.335, 25.58, 25.59, 25.7, 25.09, 24.62, 24.49, 24.75, 24.93, 25.16, 25.34, 25.86, 26.43, 26.71, 26.86, 26.0, 25.59, 26.0, 26.66, 26.18, 25.93, 26.185, 26.8, 27.03, 27.27, 27.31, 27.5, 27.06, 25.65, 25.15, 25.52, 25.92, 26.37, 26.17, 25.5, 25.335, 25.39, 26.16, 26.4, 26.51, 26.97, 27.07, 27.31, 27.2, 27.5, 27.42, 27.4, 27.47, 27.34, 27.19, 27.4, 27.23, 27.06, 27.4, 27.19, 27.0, 26.32, 26.2, 26.585, 26.4, 26.82, 27.2, 26.75, 26.5, 27.075, 27.0, 26.94, 26.51, 26.04, 25.5, 25.25, 24.96, 24.79, 24.67, 24.97, 25.04, 25.585, 25.63, 25.62, 25.8, 25.87, 25.76, 25.72, 25.87, 25.57, 26.1, 25.86, 25.88, 26.17, 26.12, 26.1, 26.19, 25.86, 26.04, 26.14, 26.15, 26.05, 26.12, 26.96, 27.47, 27.728, 28.19, 28.1, 28.15, 27.98, 28.02, 28.25, 28.65, 28.4, 28.435, 29.74, 29.95, 29.5703, 29.65, 29.7, 29.53, 29.62, 29.7, 30.05, 30.17 ...

# %% [markdown]
# ### Eh, scrolling and zooming and dynamic changes are cool, but I want to add some extra parts to this graph....including:
#
# - a line showing when Satya Nadella became CEO
# - titles for graph, x-axis, y-axis
# - A line showing the Close values

# %%
# "Layout" contains the extra visuals in the graph

layout = go.Layout({
    'title': "Microsoft Historical Stock Data",
    'yaxis': {'title': 'MSFT Stock ($)'},
    'xaxis' : {'rangeslider':{'visible':False}},
    'shapes': [{
        'x0': '2014-02-04', 'x1': '2014-02-04',
        'y0' : 0, 'y1': 1, 'xref': 'x', 'yref':'paper',
        'line' : {'color': 'rgb(30,30,30)', 'width':1}
    }],
    'annotations': [{
        'x': '2014-02-04', 'y':0.05, 'xref': 'x', 'yref': 'paper',
        'showarrow':False, 'xanchor': 'left',
        'text': 'Satya Nadella becomes CEO'
    }]
})

#### now lets create the line chart connecting all the close values together with a black line

close_line = go.Scatter(
    x=msft2.index,
    y = msft2['Close'],
    name= 'Closing $',
    line = {'color' : 'black','width' : 0.3 }
)

# create a data list containing all the charts we want to graph
data = [ ohlc_line, close_line ]

#  combine them with the layouts into a figure

fig = go.Figure(data=data, layout = layout)

# plot the data
configure_plotly_browser_state()
iplot(fig)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="490e8fc8-d01e-4ebd-891d-ef0bc26b64bc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("490e8fc8-d01e-4ebd-891d-ef0bc26b64bc", [{"name": "OHLC", "open": [30.62, 30.85, 30.88, 30.63, 30.28, 30.71, 30.15, 30.26, 30.31, 31.08, 30.75, 30.81, 30.61, 30.0, 29.24, 29.2, 29.35, 29.84, 29.9, 28.39, 28.37, 28.26, 28.38, 28.0, 28.01, 27.97, 28.03, 27.93, 27.81, 28.13, 28.53, 28.59, 28.79
, 96.11, 95.0, 95.35, 93.12, 92.31, 94.26, 95.82, 93.52, 95.0, 93.51, 94.07, 95.16, 96.22, 95.81, 96.94, 97.91, 97.7, 98.03, 97.32, 97.15, 96.18, 96.36, 97.6, 97.5, 98.66, 98.31, 98.36, 98.01, 98.95, 98.84, 100.79, 101.67, 102.19, 102.49, 100.88, 101.63, 101.05, 101.31, 100.85, 101.42, 100.13, 100.86, 100.86, 101.87, 101.14, 100.41, 98.39, 99.08, 97.54, 98.63, 98.61, 100.01, 99.05, 99.76, 101.16, 101.85, 102.12, 101.98, 104.19, 105.43, 104.91, 105.95, 105.12, 104.4, 106.27, 107.97, 107.66, 110.83, 109.62, 107.68, 105.37, 106.08, 106.28, 107.57, 108.04, 108.13, 108.88, 109.49, 109.67, 109.0, 108.21, 109.56, 107.66, 107.64, 107.58, 106.87, 105.98, 107.06, 107.56, 108.4, 109.6, 110.26, 112.02, 111.95, 112.33, 111.71, 108.49, 108.74, 108.21, 109.38, 111.24, 111.71, 112.91, 113.37, 112.14, 113.21, 111.7, 113.57, 114.26, 114.67, 114.45, 113.98, 114.41, 114.37, 115.61, 115.15, 115.17, 112.79, 112.13, 110.85, 112.26, 106.16, 105.91, 109.57, 107.6, 111.0, 110.71, 108.5, 108.66, 109.63, 108.1, 102.32, 108.3, 106.96, 103.85, 103.73, 106.81, 105.92, 106.16, 107.51, 107.72, 111.96, 111.75, 109.57, 106.87, 106.94, 104.97, 107.28, 108.29], "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", ...

# %% [markdown]
# ### Add a Regression line with SciKit Learn

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

train_x = msft3.index.value_counts().cumsum().values.reshape(-1,1)

#pandas['column].values -> converts column to numpy array

train_y = msft3['Close'].values.reshape(-1,1)

print(train_x[:5])
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %% [markdown]
# ### Create a Linear Model

# %%
# create a linear model from the LinearRegression class
reg = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
# fit data to model
reg.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Create predictions and assign them to a new column in msft3

# %%
msft3['LinReg'] = reg.predict(train_x)

# %% [markdown]
# #### Show the coefficient and the exponent for:  y = mx + b

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# [57.90678566]
# [[0.11581527]]

# %%
msft3.head(2)
# Out:
#              Open   High     Low  Close      Volume  Dividend  Split  \
# Date
# 2017-01-03  62.79  62.84  62.125  62.58  20694101.0       0.0    1.0
# 2017-01-04  62.48  62.75  62.120  62.30  21339969.0       0.0    1.0
#
#              Adj_Open   Adj_High    Adj_Low  Adj_Close  Adj_Volume     LinReg
# Date
# 2017-01-03  60.377440  60.425519  59.737991  60.175508  20694101.0  58.022601
# 2017-01-04  60.079351  60.338977  59.733183  59.906267  21339969.0  58.138416

# %% [markdown]
# ### Graph it next to the Closing price data!

# %%
linreg_line = go.Scatter(
    x=msft3.index,
    y = msft3['LinReg'],
    name= 'Linear Regression',
    line = {'color' : 'blue','width' : 1 }
)

data = [ close_line, linreg_line]

# plot the data
configure_plotly_browser_state()
iplot(data)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="deb92dbd-ead6-4ab6-ba25-af254f0a2131" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
 94.18, 94.6, 92.89, 93.13, 92.48, 89.79, 87.18, 93.78, 89.47, 89.39, 91.27, 88.52, 89.71, 92.33, 92.38, 90.23, 90.77, 92.88, 91.86, 93.58, 93.08, 94.17, 96.07, 96.44, 96.11, 95.0, 95.35, 93.12, 92.31, 94.26, 95.82, 93.52, 95.0, 93.51, 94.07, 95.16, 96.22, 95.81, 96.94, 97.91, 97.7, 98.03, 97.32, 97.15, 96.18, 96.36, 97.6, 97.5, 98.66, 98.31, 98.36, 98.01, 98.95, 98.84, 100.79, 101.67, 102.19, 102.49, 100.88, 101.63, 101.05, 101.31, 100.85, 101.42, 100.13, 100.86, 100.86, 101.87, 101.14, 100.41, 98.39, 99.08, 97.54, 98.63, 98.61, 100.01, 99.05, 99.76, 101.16, 101.85, 102.12, 101.98, 104.19, 105.43, 104.91, 105.95, 105.12, 104.4, 106.27, 107.97, 107.66, 110.83, 109.62, 107.68, 105.37, 106.08, 106.28, 107.57, 108.04, 108.13, 108.88, 109.49, 109.67, 109.0, 108.21, 109.56, 107.66, 107.64, 107.58, 106.87, 105.98, 107.06, 107.56, 108.4, 109.6, 110.26, 112.02, 111.95, 112.33, 111.71, 108.49, 108.74, 108.21, 109.38, 111.24, 111.71, 112.91, 113.37, 112.14, 113.21, 111.7, 113.57, 114.26, 114.67, 114.45, 113.98, 114.41, 114.37, 115.61, 115.15, 115.17, 112.79, 112.13, 110.85, 112.26, 106.16, 105.91, 109.57, 107.6, 111.0, 110.71, 108.5, 108.66, 109.63, 108.1, 102.32, 108.3, 106.96, 103.85, 103.73, 106.81, 105.92, 106.16, 107.51, 107.72, 111.96, 111.75, 109.57, 106.87, 106.94, 104.97, 107.28, 108.29], "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", ...

# %% [markdown]
# ### Create a 20 day moving average on the closing price values.  Whoo Rolling Averages!

# %%
msft3['20ma'] = msft3['Close'].rolling(20, min_periods=1).mean()

msft3.head(2)
# Out:
#              Open   High     Low  Close      Volume  Dividend  Split  \
# Date
# 2017-01-03  62.79  62.84  62.125  62.58  20694101.0       0.0    1.0
# 2017-01-04  62.48  62.75  62.120  62.30  21339969.0       0.0    1.0
#
#              Adj_Open   Adj_High    Adj_Low  Adj_Close  Adj_Volume     LinReg  \
# Date
# 2017-01-03  60.377440  60.425519  59.737991  60.175508  20694101.0  58.022601
# 2017-01-04  60.079351  60.338977  59.733183  59.906267  21339969.0  58.138416
#
#              20ma
# Date
# 2017-01-03  62.58
# 2017-01-04  62.44

# %% [markdown]
# ### Plot the 20 day moving average

# %%
ma_line = go.Scatter(
    x=msft3.index,
    y = msft3['20ma'],
    name= '20 Day MA',
    line = {'color' : 'green','width' : 1 }
)

data = [ close_line, linreg_line, ma_line]


# plot the data
configure_plotly_browser_state()
iplot(data)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="f5b26f5c-afb8-40ff-87b9-6952e0837f46" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
 93.12, 92.31, 94.26, 95.82, 93.52, 95.0, 93.51, 94.07, 95.16, 96.22, 95.81, 96.94, 97.91, 97.7, 98.03, 97.32, 97.15, 96.18, 96.36, 97.6, 97.5, 98.66, 98.31, 98.36, 98.01, 98.95, 98.84, 100.79, 101.67, 102.19, 102.49, 100.88, 101.63, 101.05, 101.31, 100.85, 101.42, 100.13, 100.86, 100.86, 101.87, 101.14, 100.41, 98.39, 99.08, 97.54, 98.63, 98.61, 100.01, 99.05, 99.76, 101.16, 101.85, 102.12, 101.98, 104.19, 105.43, 104.91, 105.95, 105.12, 104.4, 106.27, 107.97, 107.66, 110.83, 109.62, 107.68, 105.37, 106.08, 106.28, 107.57, 108.04, 108.13, 108.88, 109.49, 109.67, 109.0, 108.21, 109.56, 107.66, 107.64, 107.58, 106.87, 105.98, 107.06, 107.56, 108.4, 109.6, 110.26, 112.02, 111.95, 112.33, 111.71, 108.49, 108.74, 108.21, 109.38, 111.24, 111.71, 112.91, 113.37, 112.14, 113.21, 111.7, 113.57, 114.26, 114.67, 114.45, 113.98, 114.41, 114.37, 115.61, 115.15, 115.17, 112.79, 112.13, 110.85, 112.26, 106.16, 105.91, 109.57, 107.6, 111.0, 110.71, 108.5, 108.66, 109.63, 108.1, 102.32, 108.3, 106.96, 103.85, 103.73, 106.81, 105.92, 106.16, 107.51, 107.72, 111.96, 111.75, 109.57, 106.87, 106.94, 104.97, 107.28, 108.29], "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", ...

# %% [markdown]
# ### Compute Bollinger Bands with the 20 day moving standard deviation and assign a lower and upper bound based on 20 Day MA +/- 2* 20 day MSD

# %%
# 20 day standard deviation

msft3['20sd'] = msft3['Close'].rolling(20, min_periods=1).std()

# %% [markdown]
# ### Create the bands

# %%
# Upper band and lower band
msft3['Upper'] = msft3['20ma'] + 2 * msft3['20sd']

msft3['Lower'] = msft3['20ma'] - 2 * msft3['20sd']

# %% [markdown]
# ### Graph the bans together with the stock price

# %%
Upper = go.Scatter(
    x=msft3.index,
    y = msft3['Upper'],
    name= 'Upper Band',
    fill = 'tonexty',
    line = {'color' : 'light green','width' : 1 }
)

Lower = go.Scatter(
    x=msft3.index,
    y = msft3['Lower'],
    name= 'Lower Band',
    fill = 'tonexty',
    line = {'color' : 'light green','width' : 1 }
)

data = [ close_line, Upper, Lower]

layout = go.Layout({
    'title' : 'Microsoft Stock with 20 Day MA Bollinger Bands',
    'yaxis' : {'title' : 'MSFT Stock ($)'},
    'xaxis' : {'rangeslider' : {'visible':False}}
})

fig = go.Figure(data=data,layout=layout)

# plot the data
configure_plotly_browser_state()
iplot(fig)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="69c387fd-7714-4d4b-80a5-7abd325e352b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("69c387fd-7714-4d4b-80a5-7abd325e352b", [{"y": [62.58, 62.3, 62.3, 62.84, 62.64, 62.62, 63.19, 62.61, 62.7, 62.53, 62.5, 62.3, 62.74, 62.96, 63.52, 63.68, 64.27, 65.78, 65.13, 64.65, 63.58, 63.17, 63.68, 63.64, 63.43, 63.34, 64.06, 64.0, 64.72, 64.57, 64.53, 64.52, 64.62, 64.49, 64.36, 64.62
, 96.18, 96.36, 97.6, 97.5, 98.66, 98.31, 98.36, 98.01, 98.95, 98.84, 100.79, 101.67, 102.19, 102.49, 100.88, 101.63, 101.05, 101.31, 100.85, 101.42, 100.13, 100.86, 100.86, 101.87, 101.14, 100.41, 98.39, 99.08, 97.54, 98.63, 98.61, 100.01, 99.05, 99.76, 101.16, 101.85, 102.12, 101.98, 104.19, 105.43, 104.91, 105.95, 105.12, 104.4, 106.27, 107.97, 107.66, 110.83, 109.62, 107.68, 105.37, 106.08, 106.28, 107.57, 108.04, 108.13, 108.88, 109.49, 109.67, 109.0, 108.21, 109.56, 107.66, 107.64, 107.58, 106.87, 105.98, 107.06, 107.56, 108.4, 109.6, 110.26, 112.02, 111.95, 112.33, 111.71, 108.49, 108.74, 108.21, 109.38, 111.24, 111.71, 112.91, 113.37, 112.14, 113.21, 111.7, 113.57, 114.26, 114.67, 114.45, 113.98, 114.41, 114.37, 115.61, 115.15, 115.17, 112.79, 112.13, 110.85, 112.26, 106.16, 105.91, 109.57, 107.6, 111.0, 110.71, 108.5, 108.66, 109.63, 108.1, 102.32, 108.3, 106.96, 103.85, 103.73, 106.81, 105.92, 106.16, 107.51, 107.72, 111.96, 111.75, 109.57, 106.87, 106.94, 104.97, 107.28, 108.29], "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", ...

# %% [markdown]
# ### Let's create a signal book for buying and selling Microsoft Stock using the Bollinger Bands as signals

# %%
msft4 = msft3[['Close','Upper','Lower']]
msft4.head(2)
# Out:
#             Close     Upper     Lower
# Date
# 2017-01-03  62.58       NaN       NaN
# 2017-01-04  62.30  62.83598  62.04402

# %% [markdown]
# #### If the closing price is below the lower band, that is a 'buy' signal and if the closing price is above the upper band, that is a 'sell' signal

# %%
# create a new column called Signal

msft4['Signal'] = np.where(msft4['Close'] > msft4['Upper'],'SELL','HOLD')
msft4['Signal'] = np.where(msft4['Close'] < msft4['Lower'],'BUY',msft4['Signal'])

msft4 = msft4[msft4['Signal'] != 'HOLD']

msft4 = msft4[msft4['Signal'] != msft4['Signal'].shift(1)]

msft4['Symbol'] = 'MSFT'
msft4['Shares'] = 1000

msft5 = msft4

msft5
# Out:
#              Close       Upper       Lower Signal Symbol  Shares
# Date
# 2017-01-24   63.52   63.360715   62.016618   SELL   MSFT    1000
# 2017-08-10   71.41   74.549690   71.528310    BUY   MSFT    1000
# 2017-08-30   74.01   73.935255   71.582745   SELL   MSFT    1000
# 2017-12-04   81.08   85.387375   81.816625    BUY   MSFT    1000
# 2017-12-15   86.85   86.630036   80.903964   SELL   MSFT    1000
# 2018-02-08   85.01   95.984196   85.980804    BUY   MSFT    1000
# 2018-04-17   96.07   95.989556   87.217444   SELL   MSFT    1000
# 2018-06-27   97.54  103.254016   98.085984    BUY   MSFT    1000
# 2018-07-12  104.19  103.676964   97.229036   SELL   MSFT    1000
# 2018-10-10  106.16  117.329303  108.986697    BUY   MSFT    1000

# %% [markdown]
# ### Excellent!!!  We just created some trading signals by building out technical indicators and visualizing them using the Quandl API, Request web library, and the Plotly graphing library.  Please return to the original jupyter notebook file to continue on with the lesson!
